# %%
## Cross sections of photoelectric effect, Compton scattering, and pair production

import numpy as np
import matplotlib.pyplot as plt

Ee = 511                 # electron rest mass energy (keV)
Z_I = 53                 # I atomic number
Z_Na = 11                # Na atomic number
alpha = 1/137            # fine structure constant
re = 2.8179403227e-15    # classical electron radius (m)

def photoelectric(Eg, Z):
    '''
    Eg = gamma ray energy (keV)
    
    Returns photoelectric effect cross section (b)
    '''
    k = Eg/Ee
    
    if np.any(k <= 0):
        raise ValueError("All k values must be > 0")
    
    sigma = (16/3) * np.sqrt(2) * np.pi * re**2 * alpha**4 * (Z**5 / k**3.5)
    
    return sigma * (1e28) # sigma in barns

def compton(Eg, Z):
    '''
    Eg = gamma ray energy (keV)
    
    Returns Compton scattering cross section (b)
    '''
    k = Eg/Ee
    
    if np.any(k <= 0):
        raise ValueError("All k values must be > 0")
    
    term1 = (1 + k) / (k**2)
    bracket1 = (2 * (1 + k) / (1 + 2 * k)) - (np.log(1 + 2 * k) / k)
    
    term2 = np.log(1 + 2 * k) / (2 * k)
    term3 = (1 + 3 * k) / ((1 + 2 * k)**2)
    
    sigma = Z * 2 * np.pi * re**2 * (term1 * bracket1 + term2 - term3)
    
    return sigma * 1e28 # sigma in barns

def pair_prod(Eg, Z):
    '''
    Eg = gamma ray energy (keV)
    
    Returns pair production cross section (b)
    '''
    k = Eg/Ee
    
    if np.any(k <= 0):
        raise ValueError("All k values must be > 0")
    
    sigma = np.zeros_like(k)
    mask = k > 2  # Only valid for energies > 1.022 MeV = 1022 keV
    
    if np.any(mask):
        rho = (2 * k[mask] - 4) / (2 + k[mask] + 2 * np.sqrt(2 * k[mask]))
        term1 = Z**2 * alpha * re**2 * (2 * np.pi / 3)
        term2 = ((k[mask] - 2) / k[mask])**3
        rho_term = 1 + (0.5 * rho) + (23 / 40) * rho**2 + (11 / 60) * rho**3 + (29 / 960) * rho**4
        sigma[mask] = term1 * term2 * rho_term
    
    return sigma * 1e28 # sigma in barns

Eg = np.linspace(1,10000,10000) # gamma ray energy (keV)
sigma_pe = photoelectric(Eg, Z_I) + photoelectric(Eg, Z_Na)
sigma_c = compton(Eg, Z_I) + compton(Eg, Z_Na)
sigma_pp = pair_prod(Eg, Z_I) + pair_prod(Eg, Z_Na)
sigma_total = sigma_pe + sigma_c + sigma_pp

plt.figure(figsize=(10, 6))

plt.plot(Eg, sigma_pe, label="Photoelectric effect")
plt.plot(Eg, sigma_c, label="Compton scattering")
plt.plot(Eg, sigma_pp, label="Pair Production")
plt.plot(Eg, sigma_total, label="Total", linestyle="--", linewidth=2)

plt.xlabel("Energy (keV)", fontsize=14)
plt.ylabel("Cross Section (b)", fontsize=14)
plt.title("Gamma Ray Cross Sections for NaI(Tl)", fontsize=16)
plt.ylim(0,15)

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()



## Cross sections evaluated at different energies

def calculate_sigma(E_gamma):
    sigma_NaI_pe = photoelectric(E_gamma, Z_I) + photoelectric(E_gamma, Z_Na)
    sigma_NaI_c = compton(E_gamma, Z_I) + compton(E_gamma, Z_Na)
    sigma_NaI_pp = pair_prod(E_gamma, Z_I) + pair_prod(E_gamma, Z_Na)
    sigma_NaI = sigma_NaI_pe + sigma_NaI_c + sigma_NaI_pp

    ratio_pe = sigma_NaI_pe/sigma_NaI
    ratio_c = sigma_NaI_c/sigma_NaI
    ratio_pp = sigma_NaI_pp/sigma_NaI

    print("Energy (keV): ", E_gamma,
          "\n Total cross section (b): ", sigma_NaI, "\n Photoelectric ratio: ", ratio_pe,
          "\n Compton ratio: ", ratio_c, "\n Pair production ratio: ", ratio_pp)

E_gammas = [662, 1000, 1173, 1333, 1275] # gamma ray energy (keV)
for E_gamma in E_gammas:
    calculate_sigma(E_gamma)
# Out:
# Energy (keV):  662
#  Total cross section (b):  17.29594335143121
#  Photoelectric ratio:  0.05220563863035537
#  Compton ratio:  0.9477943613696447
#  Pair production ratio:  0.0
# Energy (keV):  1000
#  Total cross section (b):  13.730457933873275
#  Photoelectric ratio:  0.015523141209075867
#  Compton ratio:  0.9844768587909241
#  Pair production ratio:  0.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-fd2b154ec774> in <module>
#     111 E_gammas = [662, 1000, 1173, 1333, 1275] # gamma ray energy (keV)
#     112 for E_gamma in E_gammas:
# --> 113     calculate_sigma(E_gamma)
#
# <ipython-input-40-fd2b154ec774> in calculate_sigma(E_gamma)
#      99     sigma_NaI_pe = photoelectric(E_gamma, Z_I) + photoelectric(E_gamma, Z_Na)
#     100     sigma_NaI_c = compton(E_gamma, Z_I) + compton(E_gamma, Z_Na)
# --> 101     sigma_NaI_pp = pair_prod(E_gamma, Z_I) + pair_prod(E_gamma, Z_Na)
#     102     sigma_NaI = sigma_NaI_pe + sigma_NaI_c + sigma_NaI_pp
#     103
#
# <ipython-input-40-fd2b154ec774> in pair_prod(Eg, Z)
#      61
#      62     if np.any(mask):
# ---> 63         rho = (2 * k[mask] - 4) / (2 + k[mask] + 2 * np.sqrt(2 * k[mask]))
#      64         term1 = Z**2 * alpha * re**2 * (2 * np.pi / 3)
#      65         term2 = ((k[mask] - 2) / k[mask])**3
#
# TypeError: 'float' object is not subscriptable
